# %%
import torch

# 1. GPU가 사용 가능한지 확인
cuda_available = torch.cuda.is_available()
print(f"CUDA is available: {cuda_available}")

if cuda_available:
    # 2. 감지된 GPU 개수 확인
    gpu_count = torch.cuda.device_count()
    print(f"Number of GPUs detected: {gpu_count}")
    
    # 3. 현재 GPU 이름 확인 (RTX 4080이 보여야 함)
    gpu_name = torch.cuda.get_device_name(0)
    print(f"GPU Name: {gpu_name}")
    
    # 4. 간단한 텐서 연산을 GPU에서 수행하여 테스트
    x = torch.rand(5, 5).cuda()
    print(f"Tensor on GPU: {x.device}")
else:
    print("GPU not detected. Check CUDA installation and environment selection.")
# Out:
# CUDA is available: True
# Number of GPUs detected: 1
# GPU Name: NVIDIA GeForce RTX 4080 Laptop GPU
# Tensor on GPU: cuda:0
